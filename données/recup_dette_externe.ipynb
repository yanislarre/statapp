# %%
import pandas as pd

file_id = "1GcVpUMhTgRjHNWgmBCCoLwkPSrn92OLO"
url = f"https://drive.google.com/uc?export=download&id={file_id}"

df_dette_externe = pd.read_csv(url)
print(df_dette_externe.head())
# Out:
#   Country Name Country Code                                       Series Name  \
# 0  Afghanistan          AFG    01_Cross-border loans from BIS reporting banks
# 1  Afghanistan          AFG  02_Cross-border loans from BIS banks to nonbanks
# 2  Afghanistan          AFG                03_Official bilateral loans, total
# 3  Afghanistan          AFG            04_Official bilateral loans, aid loans
# 4  Afghanistan          AFG                05_Official bilateral loans, other
#
#                                 Series Code 1990Q1 [YR1990Q1]  \
# 0  Q.5B0.5B0.C.5A.BKL.LDPT.1.ALL.NV.TO1.ALL                ..
# 1  Q.5B0.5B0.C.5A.BKL.LDPT.1.ALL.NV.TO1.NBK                ..
# 2  Q.5A0.5A0.C.9C.GGO.LOBT.1.ALL.NV.TO1.ALL                ..
# 3  Q.5A0.5A0.C.9C.GGO.LOBA.1.ALL.NV.TO1.ALL                ..
# 4  Q.5A0.5A0.C.9C.GGO.LOBN.1.ALL.NV.TO1.ALL                ..
#
#   1990Q2 [YR1990Q2] 1990Q3 [YR1990Q3] 1990Q4 [YR1990Q4] 1991Q1 [YR1991Q1]  \
# ...

# %%
df_dette_externe.to_csv("dette_externe.csv", index=False, encoding="utf-8-sig")

# %%
display(df_dette_externe.sample(10))
# Out:
#               Country Name Country Code  \
# 7061  Virgin Islands, U.S.          VIR
# 2410               Germany          DEU
# 4480           Netherlands          NLD
# 2251      French Polynesia          PYF
# 6261            Tajikistan          TJK
# 3665                 Libya          LBY
# 4024            Mauritania          MRT
# 6645                Uganda          UGA
# 232              Argentina          ARG
# 4516  Netherlands Antilles          ANT
#
#                                             Series Name  \
# 7061                       06_Multilateral loans, total
# 2410                 03_Official bilateral loans, total
# 4480     01_Cross-border loans from BIS reporting banks
# 2251    12_Liabilities to BIS banks (cons.), short term
# 6261       18_International debt securities, short term
# 3665                     26_Portfolio investment assets
# 4024                     21_Paris Club claims (non ODA)
# 6645  10_Insured export credit exposures, short term...
# ...

# %%
print(df_dette_externe.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Series Name', 'Series Code', '1990Q1 [YR1990Q1]', '1990Q2 [YR1990Q2]', '1990Q3 [YR1990Q3]', '1990Q4 [YR1990Q4]', '1991Q1 [YR1991Q1]', '1991Q2 [YR1991Q2]', '1991Q3 [YR1991Q3]', '1991Q4 [YR1991Q4]', '1992Q1 [YR1992Q1]', '1992Q2 [YR1992Q2]', '1992Q3 [YR1992Q3]', '1992Q4 [YR1992Q4]', '1993Q1 [YR1993Q1]', '1993Q2 [YR1993Q2]', '1993Q3 [YR1993Q3]', '1993Q4 [YR1993Q4]', '1994Q1 [YR1994Q1]', '1994Q2 [YR1994Q2]', '1994Q3 [YR1994Q3]', '1994Q4 [YR1994Q4]', '1995Q1 [YR1995Q1]', '1995Q2 [YR1995Q2]', '1995Q3 [YR1995Q3]', '1995Q4 [YR1995Q4]', '1996Q1 [YR1996Q1]', '1996Q2 [YR1996Q2]', '1996Q3 [YR1996Q3]', '1996Q4 [YR1996Q4]', '1997Q1 [YR1997Q1]', '1997Q2 [YR1997Q2]', '1997Q3 [YR1997Q3]', '1997Q4 [YR1997Q4]', '1998Q1 [YR1998Q1]', '1998Q2 [YR1998Q2]', '1998Q3 [YR1998Q3]', '1998Q4 [YR1998Q4]', '1999Q1 [YR1999Q1]', '1999Q2 [YR1999Q2]', '1999Q3 [YR1999Q3]', '1999Q4 [YR1999Q4]', '2000Q1 [YR2000Q1]', '2000Q2 [YR2000Q2]', '2000Q3 [YR2000Q3]', '2000Q4 [YR2000Q4]', '2001Q1 [YR
# ...
