# %% [markdown]
# Cette section a pour but de faire les premières régressions linéaires afin d'observer le lien entre l'endetement et la croissance.

# %% [markdown]
# Commençons par une régression linéaire OLS.

# %%
pip install linearmodels
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 44.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [linearmodels] [linearmodels]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from linearmodels.iv import IV2SLS

# %% [markdown]
# régression linéaire sans contrôles (définir x et y)

# %%
print("\n" + "="*60)
print("MODÈLE 1 : Approche Naïve (y ~ x)")
print("="*60)
model_naive = smf.ols('y ~ x', data=df_ml).fit()
coef_x = model_naive.params['x']
pval_x = model_naive.pvalues['x']

print(f"R-squared: {model_naive.rsquared:.4f}")
print(f"Impact 'x' : {coef_x:.2f} y")
print(f"Significativité (p-value) : {pval_x:.4f}")

# %% [markdown]
# Régression linéaire avec contrôles (définir y et x_controle)

# %%
print("\n" + "="*60)
print("MODÈLE 2 : Approche Fondamentale (Contrôle des facteurs)")
print("="*60)

formula_full = """
y ~ x_controle
"""

model_full = smf.ols(formula_full, data=df_ml).fit(cov_type='HC3')

print(f"R-squared: {model_full.rsquared:.4f}")
print("-" * 30)

print(model_full.summary())

# %% [markdown]
# plot la qualité des prédictions

# %%
y_test_raw = model_full.model.endog  
y_pred_real = model_full.fittedvalues

plt.figure(figsize=(10, 6))
plt.scatter(y_test_raw, y_pred_real, alpha=0.6, s=50, color='steelblue')

plt.plot([y_test_raw.min(), y_test_raw.max()], [y_test_raw.min(), y_test_raw.max()],'r--', lw=2, label='Prédiction Parfaite')
plt.xlabel('y', fontsize=12, fontweight='bold')
plt.ylabel('y Prédit', fontsize=12, fontweight='bold')
plt.title(f'Qualité des Prédictions (R² = {model_full.rsquared:.4f})', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Variable instrumentale

# %%
# Z: Instrument 
Z = 
# X: Variable endogène 
X =
# Y: Variable dépendante 
Y =
# C : Variable de contrôle exogène
C = 

# ---------------------------------------------------------
# Définition et Estimation du Modèle IV (2SLS)
# ---------------------------------------------------------

# La syntaxe de la formule est : Dep ~ Exog + [Endog ~ Instr]
# Note : '1' est ajouté pour inclure la constante (intercept)
formula_iv = 'Y ~ 1 + C + [X ~ Z]'


model_iv = IV2SLS.from_formula(formula_iv, data=df_ml)
results = model_iv.fit(cov_type='robust')
print(results)
